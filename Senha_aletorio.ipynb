# %%
import string
import random

letras = string.ascii_letters
numeros = string.digits
resto = '!@#$_&-+'
total = letras + numeros + resto
senha = ''.join(random.choices (total, k=8))
print (senha)
# Out:
# xtd0viuO
